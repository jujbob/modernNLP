# %% [markdown]
# # 필요 라이브러리

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %% [markdown]
# # 하이퍼파라미터 & 데이터

# %%
# hidden_state 크기
n_hidden = 50

# learning rate
lr = 0.01

# number of epoch
epochs = 2000

# 예제 문장
sentence = 'hello pytorch. how long can a rnn cell remember?'

# vocab에 사용할 문자열들
# 알파벳(0-25), 특수기호(26-32), start(33), end(34)
characters = "abcdefghijklmnopqrstuvwxyz ?!.,:;01"

character_list = [c for c in characters]

char_len = len(character_list)

# %% [markdown]
# # Sentence to One-hot
# - 문장을 one-hot vector 행렬로 출력하는 함수
# - 구조
#   - start-one-hot, characters-one-hot , end-one-hot

# %%
def sentence_to_onehot(sentence):
  # ToDo


  return output

# %% [markdown]
# # One-hot to Word
# - 원-핫 벡터를 워드로 변환하는 함수

# %%
def onehot_to_word(onehot_1):
  # ToDo

# %% [markdown]
# # RNN Class
#
# ![image.png](data:image/png;base64,...)

# %%
class RNN(nn.Module):
  def __init__(self,input_size,hidden_size,output_size):
    super(RNN,self).__init__()

    # ToDo


  def forward(self,input,hidden):
    # ToDo

    return output,hidden

  # h_0 초기화
  def init_hidden(self):
    return torch.zeros(1,self.hidden_size)

# %%
rnn = RNN(char_len,n_hidden,char_len)

# %%
# ToDo -> torch의 MSELoss와 Adam optimizer 사용
loss_func =
optimizer =

# %% [markdown]
# # Train
# ![image.png](data:image/png;base64,...)

# %%
onehot = torch.from_numpy(sentence_to_onehot(sentence)).type_as(torch.FloatTensor())

for i in range(epochs):
  rnn.zero_grad()
  total_loss = 0
  hidden = rnn.init_hidden()

  # ToDo


  if i%10 == 0:
    print(total_loss)

# %% [markdown]
# # inference 구현

# %%
# ToDo
