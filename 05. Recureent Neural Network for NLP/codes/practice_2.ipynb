# %% [markdown]
# # 입력 문자열에 따른 다음 문자열 예측 모델 만들기

# %% [markdown]
# - 예제) hello -> ello
#   - h -> e
#   - e -> l
#   - l -> l
#   - o -> ?

# %% [markdown]
# # 라이브러리 임포트

# %%
import torch
import torch.optim as optim
import pandas as pd
import numpy as np

# %% [markdown]
# # 데이터 전처리

# %%
# 예제 문장
example = ' if you want you'

# %%
# 문자열 vocab 만들기 - 딕셔너리 형식
# ToDo
word_to_id = {}
id_to_word = {}

# %%
vocab_size =
hidden_size = vocab_size
learning_rate = 0.1

# %%
# one-hot input/target 만들기
# ToDo
example_idx =
x_data =
x_one_hot =
y_data =

# %%
# x_one_hot 텐서 변환 (Long? Float?)
X =

# y_data 텐서 변환 (Long? Float?)
Y =

# %%
# hint np.eye를 사용하면 원-핫 벡터를 쉽게 만들 수 있음
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# # 모델 구현

# %%
input_size = vocab_size
hidden_size = #자유롭게 설정
rnn = nn.RNN(input_size,hidden_size,batch_first=True)

# %%
# ToDo
# loss function , optimizer 설정
# 다음 단어예측은 어떤 loss function을 사용?
# optimizer는 Adam으로
learning_rate = 0.001
loss_function =
optimizer =

# %%
# 출력 예시 확인해보기
output,_ = rnn(X)
print(X.size())
print(output.size())

# %% [markdown]
# # 학습 구현

# %%
for i in range(50):
  rnn.train()
  optimizer.zero_grad()
  output,_ = rnn(X)

  loss = loss_fn(output.reshape(-1,10),Y.reshape(-1))

  # 가장 높은 확률을 가지는 id 값 가져오기 hint) argmax
  result =

  result_str = ''.join([id_to_word[c] for c in np.squeeze(result)])
  print(i, "loss: ", loss.item(), "prediction: ", result, "true Y: ", y_data, "prediction str: ", result_str)

  # ToDo - loss backpropagation

  # ToDo - 파라미터 업데이트
